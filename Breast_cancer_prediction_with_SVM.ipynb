# %% [markdown]
# # Support Vector Machines (SVMs) using scikit-learn in Python
# Hi Guys,<br>
#
# Welcome to the Support Vector Machines lecture using scikit-learn in Python.<br>
#
# As suggested in the theory lecture, we are going to work with a real dataset on [Breast Cancer Wisconsin (Diagnostic)](https://www.kaggle.com/uciml/breast-cancer-wisconsin-data/data). <br><br>
#
# <font style="font-size:12px;color:green;">&#9758; The dataset is available on kaggle and originally belong to [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29). This dataset was donated to UCI by Nick Street in 1995 for the public use. [Relevant Papers](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29) and [detailed description](https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.names) on the dataset is provided at UCI website.<br></font>
#
# Because we have worked with this dataset in Logistic Regression and KNN sections, so, this will allow us to compare the SVM to those models. However, in the SVM project, we will work with another new and real life dataset on credit approval. <br>
#
# &#9758; Breast cancer dataset can be loaded from Scikit-learn. Its up to you if you want to load from scikit-learn or use csv data file which is provided in the course material.<br>
# I am going to load the one which is in the course material!<br>
# First thing first, let's import some libraries!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Breast_Cancer_Diagnostic.csv')

# %%
df
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      fractal_dimension_mean diagnosis
# 0                   0.07871         M
# 1                   0.05667         M
# 2                   0.05999         M
# 3                   0.09744         M
# 4                   0.05883         M
# ..                      ...       ...
# 564                 0.05623         M
# 565                 0.05533         M
# 566                 0.05648         M
# 567                 0.07016         M
# 568                 0.05884         B
#
# [569 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# radius_mean               0
# texture_mean              0
# perimeter_mean            0
# area_mean                 0
# smoothness_mean           0
# compactness_mean          0
# concavity_mean            0
# concave points_mean       0
# symmetry_mean             0
# fractal_dimension_mean    0
# diagnosis                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   radius_mean             569 non-null    float64
#  1   texture_mean            569 non-null    float64
#  2   perimeter_mean          569 non-null    float64
#  3   area_mean               569 non-null    float64
#  4   smoothness_mean         569 non-null    float64
#  5   compactness_mean        569 non-null    float64
#  6   concavity_mean          569 non-null    float64
#  7   concave points_mean     569 non-null    float64
#  8   symmetry_mean           569 non-null    float64
#  9   fractal_dimension_mean  569 non-null    float64
#  10  diagnosis               569 non-null    object
# dtypes: float64(10), object(1)
# memory usage: 49.0+ KB

# %%
x = df.drop('diagnosis',axis = 1)
y = df['diagnosis']

# %%
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      fractal_dimension_mean
# 0                   0.07871
# 1                   0.05667
# 2                   0.05999
# 3                   0.09744
# 4                   0.05883
# ..                      ...
# 564                 0.05623
# 565                 0.05533
# 566                 0.05648
# 567                 0.07016
# 568                 0.05884
#
# [569 rows x 10 columns]

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
#now scaling for features
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
x_scaler = mms.fit_transform(x)
x_scaler
# Out:
# array([[0.52103744, 0.0226581 , 0.54598853, ..., 0.73111332, 0.68636364,
#         0.60551811],
#        [0.64314449, 0.27257355, 0.61578329, ..., 0.34875746, 0.37979798,
#         0.14132266],
#        [0.60149557, 0.3902604 , 0.59574321, ..., 0.63568588, 0.50959596,
#         0.21124684],
#        ...,
#        [0.45525108, 0.62123774, 0.44578813, ..., 0.26351889, 0.26767677,
#         0.13732098],
#        [0.64456434, 0.66351031, 0.66553797, ..., 0.7554672 , 0.67525253,
#         0.42544229],
#        [0.03686876, 0.50152181, 0.02853984, ..., 0.        , 0.26616162,
#         0.18702612]], shape=(569, 10))

# %%
x_scaler.shape
# Out:
# (569, 10)

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaler,y,test_size = 0.20,random_state = 42)

# %%
x_train
# Out:
# array([[0.09692839, 0.25769361, 0.10365559, ..., 0.21744533, 0.53080808,
#         0.64237574],
#        [0.66775522, 0.57017247, 0.68350494, ..., 0.74353877, 0.67424242,
#         0.50589722],
#        [0.10374367, 0.14034494, 0.10648884, ..., 0.1083499 , 0.6469697 ,
#         0.4142797 ],
#        ...,
#        [0.34592267, 0.2404464 , 0.32140142, ..., 0.03106362, 0.22626263,
#         0.0800337 ],
#        [0.33125089, 0.33513696, 0.32706793, ..., 0.32122266, 0.30757576,
#         0.32603201],
#        [0.24605992, 0.36557322, 0.23101375, ..., 0.08797217, 0.34292929,
#         0.14342881]], shape=(455, 10))

# %%
x_train.shape
# Out:
# (455, 10)

# %%
x_test
# Out:
# array([[0.25978513, 0.30064254, 0.25775689, ..., 0.18991054, 0.43686869,
#         0.29001685],
#        [0.56599934, 0.39228948, 0.55151683, ..., 0.39517893, 0.26363636,
#         0.09793597],
#        [0.4012968 , 0.33040243, 0.40017967, ..., 0.40193837, 0.43989899,
#         0.168492  ],
#        ...,
#        [0.21482323, 0.17653027, 0.207864  , ..., 0.14557654, 0.41565657,
#         0.24684078],
#        [0.34260968, 0.61345959, 0.33694976, ..., 0.21908549, 0.14242424,
#         0.23862679],
#        [0.65071702, 0.72404464, 0.63513233, ..., 0.42972167, 0.35808081,
#         0.14279697]], shape=(114, 10))

# %%
x_test.shape
# Out:
# (114, 10)

# %%
y_train
# Out:
# 68     B
# 181    M
# 63     B
# 248    B
# 60     B
#       ..
# 71     B
# 106    B
# 270    B
# 435    M
# 102    B
# Name: diagnosis, Length: 455, dtype: object

# %%
y_test.shape
# Out:
# (114,)

# %%
y_test
# Out:
# 204    B
# 70     M
# 131    M
# 431    B
# 540    B
#       ..
# 486    B
# 75     M
# 249    B
# 238    B
# 265    M
# Name: diagnosis, Length: 114, dtype: object

# %%
from sklearn.svm import SVC
svm_model = SVC()
svm_model.fit(x_train,y_train)
# Out:
# SVC()

# %%
svm_model.score(x_test,y_test)
# Out:
# 0.9736842105263158

# %%
svm_model = SVC(kernel = 'linear', C = 30, gamma = 'auto')
svm_model.fit(x_train,y_train)
# Out:
# SVC(C=30, gamma='auto', kernel='linear')

# %%
svm_model.score(x_test,y_test)
# Out:
# 0.9298245614035088

# %% [markdown]
# # Now Using GridSerachCV(hyperperametar Tuning)

# %%
cancer_data = pd.read_csv('Breast_Cancer_Diagnostic.csv')
cancer_data
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      fractal_dimension_mean diagnosis
# 0                   0.07871         M
# 1                   0.05667         M
# 2                   0.05999         M
# 3                   0.09744         M
# 4                   0.05883         M
# ..                      ...       ...
# 564                 0.05623         M
# 565                 0.05533         M
# 566                 0.05648         M
# 567                 0.07016         M
# 568                 0.05884         B
#
# [569 rows x 11 columns]

# %%
x = cancer_data.drop(['diagnosis'],axis=1)
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      fractal_dimension_mean
# 0                   0.07871
# 1                   0.05667
# 2                   0.05999
# 3                   0.09744
# 4                   0.05883
# ..                      ...
# 564                 0.05623
# 565                 0.05533
# 566                 0.05648
# 567                 0.07016
# 568                 0.05884
#
# [569 rows x 10 columns]

# %%
y=cancer_data['diagnosis']
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
type(y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Now scaling features

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
x_scaler = mms.fit_transform(x)
x_scaler
# Out:
# array([[0.52103744, 0.0226581 , 0.54598853, ..., 0.73111332, 0.68636364,
#         0.60551811],
#        [0.64314449, 0.27257355, 0.61578329, ..., 0.34875746, 0.37979798,
#         0.14132266],
#        [0.60149557, 0.3902604 , 0.59574321, ..., 0.63568588, 0.50959596,
#         0.21124684],
#        ...,
#        [0.45525108, 0.62123774, 0.44578813, ..., 0.26351889, 0.26767677,
#         0.13732098],
#        [0.64456434, 0.66351031, 0.66553797, ..., 0.7554672 , 0.67525253,
#         0.42544229],
#        [0.03686876, 0.50152181, 0.02853984, ..., 0.        , 0.26616162,
#         0.18702612]], shape=(569, 10))

# %% [markdown]
# ### using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

clf = GridSearchCV((SVC()),{
    'gamma':['auto','scale'],
    'C':[1,5,10,15],
    'kernel':['rbf','linear','poly']
},cv=5)
clf.fit(x_scaler,y)
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.00785494, 0.00528779, 0.00924821, 0.00589247, 0.00382228,
#         0.00595975, 0.00458908, 0.0043623 , 0.00683112, 0.00587492,
#         0.00409431, 0.00868402, 0.00479169, 0.00374417, 0.00439024,
#         0.0046319 , 0.00356855, 0.0124177 , 0.00500302, 0.00504541,
#         0.0043447 , 0.00631371, 0.00598292, 0.01396937]),
#  'std_fit_time': array([9.04871865e-04, 1.27085693e-03, 1.78671413e-03, 5.84950767e-04,
#         1.50843906e-04, 5.15643003e-04, 5.98076130e-04, 3.75809985e-04,
#         6.26908013e-04, 2.28589955e-04, 1.53917200e-04, 9.03934739e-04,
#         1.63738645e-04, 2.72719358e-04, 9.75560348e-05, 1.72514952e-04,
#         3.59143435e-04, 3.21346655e-03, 2.44567282e-04, 8.03560144e-04,
#         1.90050148e-04, 4.42130489e-04, 2.12778773e-03, 1.69722120e-03]),
#  'mean_score_time': array([0.00565643, 0.00264153, 0.00333099, 0.00386605, 0.00186014,
#         0.00170541, 0.00321636, 0.00221477, 0.00281205, 0.00327415,
#         0.00209332, 0.0016335 , 0.00348058, 0.00154476, 0.00191369,
#         0.00241528, 0.00158176, 0.00201616, 0.00351892, 0.00219817,
#         0.00191627, 0.00304365, 0.00224986, 0.00191941]),
#  'std_score_time': array([8.99999314e-04, 4.81765399e-04, 4.66600239e-04, 7.48251124e-04,
#         5.16113174e-05, 7.28890479e-05, 4.77099099e-04, 1.27612760e-04,
#         3.29457300e-04, 9.60470541e-05, 7.35392049e-05, 1.62767482e-04,
#         4.91365563e-04, 7.50195946e-05, 1.46845222e-04, 3.11059412e-05,
#         3.92395553e-05, 1.76911765e-04, 4.26679117e-04, 3.83136636e-04,
#         1.73584026e-04, 1.40717950e-04, 6.60031418e-04, 2.56633502e-04]),
#  'param_C': masked_array(data=[1, 1, 1, 1, 1, 1, 5, 5, 5, 5, 5, 5, 10, 10, 10, 10, 10,
#                     10, 15, 15, 15, 15, 15, 15],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_gamma': masked_array(data=['auto', 'auto', 'auto', 'scale', 'scale', 'scale',
#                     'auto', 'auto', 'auto', 'scale', 'scale', 'scale',
#                     'auto', 'auto', 'auto', 'scale', 'scale', 'scale',
#                     'auto', 'auto', 'auto', 'scale', 'scale', 'scale'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'poly', 'rbf', 'linear', 'poly',
#                     'rbf', 'linear', 'poly', 'rbf', 'linear', 'poly',
#                     'rbf', 'linear', 'poly', 'rbf', 'linear', 'poly',
#                     'rbf', 'linear', 'poly', 'rbf', 'linear', 'poly'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'params': [{'C': 1, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 1, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 1, 'gamma': 'auto', 'kernel': 'poly'},
#   {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 1, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 1, 'gamma': 'scale', 'kernel': 'poly'},
#   {'C': 5, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 5, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 5, 'gamma': 'auto', 'kernel': 'poly'},
#   {'C': 5, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 5, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 5, 'gamma': 'scale', 'kernel': 'poly'},
#   {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 10, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 10, 'gamma': 'auto', 'kernel': 'poly'},
#   {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 10, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 10, 'gamma': 'scale', 'kernel': 'poly'},
#   {'C': 15, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 15, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 15, 'gamma': 'auto', 'kernel': 'poly'},
#   {'C': 15, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 15, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 15, 'gamma': 'scale', 'kernel': 'poly'}],
#  'split0_test_score': array([0.85964912, 0.88596491, 0.65789474, 0.9122807 , 0.88596491,
#         0.92105263, 0.88596491, 0.88596491, 0.8245614 , 0.94736842,
#         0.88596491, 0.93859649, 0.88596491, 0.88596491, 0.83333333,
#         0.94736842, 0.88596491, 0.93859649, 0.88596491, 0.87719298,
#         0.84210526, 0.93859649, 0.87719298, 0.94736842]),
#  'split1_test_score': array([0.92105263, 0.92982456, 0.68421053, 0.93859649, 0.92982456,
#         0.96491228, 0.93859649, 0.92982456, 0.80701754, 0.96491228,
#         0.92982456, 0.96491228, 0.92982456, 0.93859649, 0.85964912,
#         0.96491228, 0.93859649, 0.96491228, 0.92982456, 0.93859649,
#         0.88596491, 0.96491228, 0.93859649, 0.96491228]),
#  'split2_test_score': array([0.92982456, 0.94736842, 0.68421053, 0.94736842, 0.94736842,
#         0.94736842, 0.94736842, 0.95614035, 0.83333333, 0.94736842,
#         0.95614035, 0.93859649, 0.95614035, 0.94736842, 0.86842105,
#         0.93859649, 0.94736842, 0.94736842, 0.95614035, 0.94736842,
#         0.86842105, 0.92982456, 0.94736842, 0.94736842]),
#  'split3_test_score': array([0.93859649, 0.96491228, 0.70175439, 0.97368421, 0.96491228,
#         0.94736842, 0.96491228, 0.96491228, 0.88596491, 0.97368421,
#         0.96491228, 0.95614035, 0.96491228, 0.95614035, 0.90350877,
#         0.97368421, 0.95614035, 0.95614035, 0.96491228, 0.95614035,
#         0.9122807 , 0.96491228, 0.95614035, 0.95614035]),
#  'split4_test_score': array([0.95575221, 0.96460177, 0.69911504, 0.92920354, 0.96460177,
#         0.97345133, 0.96460177, 0.94690265, 0.91150442, 0.94690265,
#         0.94690265, 0.96460177, 0.96460177, 0.9380531 , 0.92920354,
#         0.94690265, 0.9380531 , 0.96460177, 0.95575221, 0.92035398,
#         0.9380531 , 0.94690265, 0.92035398, 0.95575221]),
#  'mean_test_score': array([0.920975  , 0.93853439, 0.68543704, 0.94022667, 0.93853439,
#         0.95083062, 0.94028878, 0.93674895, 0.85247632, 0.9560472 ,
#         0.93674895, 0.95256948, 0.94028878, 0.93322465, 0.87882316,
#         0.95429281, 0.93322465, 0.95432386, 0.93851886, 0.92793045,
#         0.88936501, 0.94902965, 0.92793045, 0.95430834]),
#  'std_test_score': array([0.03273883, 0.02930103, 0.01558801, 0.02037428, 0.02930103,
#         0.01800384, 0.02898795, 0.02792584, 0.03954238, 0.01117067,
#         0.02792584, 0.01183521, 0.03003096, 0.02453907, 0.03374236,
#         0.012944  , 0.02453907, 0.0101664 , 0.02878064, 0.02799675,
#         0.03340465, 0.01404796, 0.02799675, 0.00654537]),
#  'rank_test_score': array([20, 11, 24, 10, 11,  6,  9, 14, 23,  1, 14,  5,  8, 16, 22,  4, 16,
#          2, 13, 18, 21,  7, 18,  3], dtype=int32)}

# %%
data = pd.DataFrame(clf.cv_results_)
data
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.007855      0.000905         0.005656        0.000900        1
# 1        0.005288      0.001271         0.002642        0.000482        1
# 2        0.009248      0.001787         0.003331        0.000467        1
# 3        0.005892      0.000585         0.003866        0.000748        1
# 4        0.003822      0.000151         0.001860        0.000052        1
# 5        0.005960      0.000516         0.001705        0.000073        1
# 6        0.004589      0.000598         0.003216        0.000477        5
# 7        0.004362      0.000376         0.002215        0.000128        5
# 8        0.006831      0.000627         0.002812        0.000329        5
# 9        0.005875      0.000229         0.003274        0.000096        5
# 10       0.004094      0.000154         0.002093        0.000074        5
# 11       0.008684      0.000904         0.001634        0.000163        5
# 12       0.004792      0.000164         0.003481        0.000491       10
# 13       0.003744      0.000273         0.001545        0.000075       10
# 14       0.004390      0.000098         0.001914        0.000147       10
# 15       0.004632      0.000173         0.002415        0.000031       10
# 16       0.003569      0.000359         0.001582        0.000039       10
# 17       0.012418      0.003213         0.002016        0.000177       10
# 18       0.005003      0.000245         0.003519        0.000427       15
# 19       0.005045      0.000804         0.002198        0.000383       15
# 20       0.004345      0.000190         0.001916        0.000174       15
# 21       0.006314      0.000442         0.003044        0.000141       15
# 22       0.005983      0.002128         0.002250        0.000660       15
# 23       0.013969      0.001697         0.001919        0.000257       15
#
#    param_gamma param_kernel                                           params  \
# 0         auto          rbf       {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 1         auto       linear    {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# 2         auto         poly      {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}
# 3        scale          rbf      {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 4        scale       linear   {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 5        scale         poly     {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 6         auto          rbf       {'C': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# 7         auto       linear    {'C': 5, 'gamma': 'auto', 'kernel': 'linear'}
# 8         auto         poly      {'C': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 9        scale          rbf      {'C': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# 10       scale       linear   {'C': 5, 'gamma': 'scale', 'kernel': 'linear'}
# 11       scale         poly     {'C': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 12        auto          rbf      {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# 13        auto       linear   {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 14        auto         poly     {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}
# 15       scale          rbf     {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 16       scale       linear  {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 17       scale         poly    {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 18        auto          rbf      {'C': 15, 'gamma': 'auto', 'kernel': 'rbf'}
# 19        auto       linear   {'C': 15, 'gamma': 'auto', 'kernel': 'linear'}
# 20        auto         poly     {'C': 15, 'gamma': 'auto', 'kernel': 'poly'}
# 21       scale          rbf     {'C': 15, 'gamma': 'scale', 'kernel': 'rbf'}
# 22       scale       linear  {'C': 15, 'gamma': 'scale', 'kernel': 'linear'}
# 23       scale         poly    {'C': 15, 'gamma': 'scale', 'kernel': 'poly'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.859649           0.921053           0.929825
# 1            0.885965           0.929825           0.947368
# 2            0.657895           0.684211           0.684211
# 3            0.912281           0.938596           0.947368
# 4            0.885965           0.929825           0.947368
# 5            0.921053           0.964912           0.947368
# 6            0.885965           0.938596           0.947368
# 7            0.885965           0.929825           0.956140
# 8            0.824561           0.807018           0.833333
# 9            0.947368           0.964912           0.947368
# 10           0.885965           0.929825           0.956140
# 11           0.938596           0.964912           0.938596
# 12           0.885965           0.929825           0.956140
# 13           0.885965           0.938596           0.947368
# 14           0.833333           0.859649           0.868421
# 15           0.947368           0.964912           0.938596
# 16           0.885965           0.938596           0.947368
# 17           0.938596           0.964912           0.947368
# 18           0.885965           0.929825           0.956140
# 19           0.877193           0.938596           0.947368
# 20           0.842105           0.885965           0.868421
# 21           0.938596           0.964912           0.929825
# 22           0.877193           0.938596           0.947368
# 23           0.947368           0.964912           0.947368
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.938596           0.955752         0.920975        0.032739
# 1            0.964912           0.964602         0.938534        0.029301
# 2            0.701754           0.699115         0.685437        0.015588
# 3            0.973684           0.929204         0.940227        0.020374
# 4            0.964912           0.964602         0.938534        0.029301
# 5            0.947368           0.973451         0.950831        0.018004
# 6            0.964912           0.964602         0.940289        0.028988
# 7            0.964912           0.946903         0.936749        0.027926
# 8            0.885965           0.911504         0.852476        0.039542
# 9            0.973684           0.946903         0.956047        0.011171
# 10           0.964912           0.946903         0.936749        0.027926
# 11           0.956140           0.964602         0.952569        0.011835
# 12           0.964912           0.964602         0.940289        0.030031
# 13           0.956140           0.938053         0.933225        0.024539
# 14           0.903509           0.929204         0.878823        0.033742
# 15           0.973684           0.946903         0.954293        0.012944
# 16           0.956140           0.938053         0.933225        0.024539
# 17           0.956140           0.964602         0.954324        0.010166
# 18           0.964912           0.955752         0.938519        0.028781
# 19           0.956140           0.920354         0.927930        0.027997
# 20           0.912281           0.938053         0.889365        0.033405
# 21           0.964912           0.946903         0.949030        0.014048
# 22           0.956140           0.920354         0.927930        0.027997
# 23           0.956140           0.955752         0.954308        0.006545
#
#     rank_test_score
# 0                20
# 1                11
# 2                24
# 3                10
# 4                11
# 5                 6
# 6                 9
# 7                14
# 8                23
# 9                 1
# 10               14
# 11                5
# 12                8
# 13               16
# 14               22
# 15                4
# 16               16
# 17                2
# 18               13
# 19               18
# 20               21
# 21                7
# 22               18
# 23                3

# %%
best_results = clf.best_score_
best_results
# Out:
# np.float64(0.956047197640118)

# %%
best_params = clf.best_params_
best_params
# Out:
# {'C': 5, 'gamma': 'scale', 'kernel': 'rbf'}

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
sv1 = cross_val_score(SVC(kernel='poly',C=10,gamma = 'scale'),x_scaler,y,cv=5)
sv1
# Out:
# array([0.93859649, 0.96491228, 0.94736842, 0.95614035, 0.96460177])

# %%
sv1.mean()
# Out:
# np.float64(0.9543238627542306)

# %%
sv2 = cross_val_score(SVC(kernel='rbf',C=1,gamma = 'auto'),x_scaler,y,cv=5)
sv2
# Out:
# array([0.85964912, 0.92105263, 0.92982456, 0.93859649, 0.95575221])

# %%
sv2.mean()
# Out:
# np.float64(0.9209750038813848)
